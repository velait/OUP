# %%
# %load_ext autoreload
# %autoreload 2

# avoid GPU due to Cholesky decompositions
import os
os.environ["CUDA_VISIBLE_DEVICES"]="-1"

import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf
sess = tf.InteractiveSession()

import numpy as np
import pandas as pd
from utils import gen_data
from npde_helper import npde_fit
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
np.random.seed(918273)
x0,t,Y,X,D,f,g = gen_data('vdp-cdiff', Ny=[35,40,30], tend=8, nstd=0.1)

# %%
# npde = npde_fit(sess, t, Y, model='sde')
t
# Out:
# array([ array([ 0.        ,  0.23529412,  0.47058824,  0.70588235,  0.94117647,
#         1.17647059,  1.41176471,  1.64705882,  1.88235294,  2.11764706,
#         2.35294118,  2.58823529,  2.82352941,  3.05882353,  3.29411765,
#         3.52941176,  3.76470588,  4.        ,  4.23529412,  4.47058824,
#         4.70588235,  4.94117647,  5.17647059,  5.41176471,  5.64705882,
#         5.88235294,  6.11764706,  6.35294118,  6.58823529,  6.82352941,
#         7.05882353,  7.29411765,  7.52941176,  7.76470588,  8.        ]),
#        array([ 0.        ,  0.20512821,  0.41025641,  0.61538462,  0.82051282,
#         1.02564103,  1.23076923,  1.43589744,  1.64102564,  1.84615385,
#         2.05128205,  2.25641026,  2.46153846,  2.66666667,  2.87179487,
#         3.07692308,  3.28205128,  3.48717949,  3.69230769,  3.8974359 ,
#         4.1025641 ,  4.30769231,  4.51282051,  4.71794872,  4.92307692,
#         5.12820513,  5.33333333,  5.53846154,  5.74358974,  5.94871795,
# ...

# %%
# Read data 

df = pd.read_csv("/Users/villelaitinen/Desktop/PhD/OUP_dev/NPDE/ravel_df.csv")

t = df.iloc[:, 2].values
Y = df.iloc[:, 0:2].values

t2 = [t]

Y2 = [Y]

Y2[0]
# Out:
# array([[ 6.3672462 , -4.44371088],
#        [ 5.97049235, -3.41992504],
#        [ 5.5737385 , -2.39613921],
#        [ 5.17698465, -1.37235337],
#        [ 4.78023079, -0.34856753],
#        [ 5.34552597, -1.86169658],
#        [ 5.91082116, -3.37482564],
#        [ 6.47611634, -4.88795469],
#        [ 6.21108791, -4.64834924],
#        [ 5.94605949, -4.40874379],
#        [ 5.68103106, -4.16913834],
#        [ 5.41600263, -3.92953289],
#        [ 5.89888722, -3.89078728],
#        [ 6.38177181, -3.85204168],
#        [ 6.86465639, -3.81329608],
#        [ 6.80747948, -4.03186258],
#        [ 6.75030256, -4.25042907],
#        [ 6.69312565, -4.46899557],
#        [ 6.63594874, -4.68756207],
#        [ 6.55807428, -4.72155218],
#        [ 6.48019982, -4.75554229],
#        [ 6.40232536, -4.7895324 ],
#        [ 6.33738281, -4.8106597 ],
#        [ 6.27244025, -4.83178701],
#        [ 6.2074977 , -4.85291431],
#        [ 6.14255515, -4.87404161],
#        [ 5.96984958, -4.46876912],
# ...

# %%
npde = npde_fit(sess, t2, Y2, model='sde')
# Out:
# Model being initialized...
# WARNING:tensorflow:From /Users/villelaitinen/Desktop/PhD/OUP_dev/NPDE/npde-master/npde_helper.py:155: MultivariateNormalFullCovariance.__init__ (from tensorflow.contrib.distributions.python.ops.mvn_full_covariance) is deprecated and will be removed after 2018-10-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.contrib.distributions`.
# WARNING:tensorflow:From /Users/villelaitinen/Desktop/PhD/OUP_dev/NPDE/npde-master/npde_helper.py:155: MultivariateNormalFullCovariance.__init__ (from tensorflow.contrib.distributions.python.ops.mvn_full_covariance) is deprecated and will be removed after 2018-10-01.
# Instructions for updating:
# ...

# %%
npde.
# Out:
# <bound method NPSDE.sample of <npde.NPSDE object at 0x130fcb908>>
